# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# Define the path to the assignment folder
import os
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = "DL and AdvAI"  # Replace with your folder name
GOOGLE_DRIVE_PATH = os.path.join('drive', 'MyDrive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))  # Verify files are present

# Add the folder to Python path
import sys
sys.path.append(GOOGLE_DRIVE_PATH)

# Enable autoreload
# %load_ext autoreload
# %autoreload 2
# Out:
# Mounted at /content/drive
# ['__init__.py', '__pycache__', 'HW1.ipynb', 'utils.py']

# %%
# Import the utils module
from utils import hello, calculate_square, add_numbers, um_id, unique_name

# Test hello function
hello()
# Out:
# Hello Deep Learning

# %%
number = 10.0
number_sq = calculate_square(number)

assert number_sq == number * number
print(f"Expected: {number * number}, Got: {number_sq}")
# Out:
# Expected: 100.0, Got: 100.0

# %%
# Test add_numbers
a = 10.0
b = 24.0
a_plus_b = add_numbers(a, b)

assert a_plus_b == a + b
print(f"Expected: {a + b}, Got: {a_plus_b}")
# Out:
# Expected: 34.0, Got: 34.0

# %%
# Test um_id
my_um_id = um_id()
assert my_um_id is not None
assert isinstance(my_um_id, str)
assert len(my_um_id) == 8
print(f"My UMID: {my_um_id}")
# Out:
# My UMID: 82653870

# %%
# Test unique_name
my_unique_name = unique_name()
assert my_unique_name is not None
print(f"My Unique Name: {my_unique_name}")
# Out:
# My Unique Name: dharshaa

# %%
# !pip install datasets

# %%
from datasets import load_dataset

# Load the MNIST dataset (first 100 training examples)
mnist_data = load_dataset("mnist", split="train[:100]")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
first_image = mnist_data[0]["image"]
first_image.show()  # This will display the image

# %%
first_label = mnist_data[0]["label"]
print(f"Label: {first_label}")
# Out:
# Label: 5

# %%
# !pip install torch torchvision matplotlib

# %%
import torch
from torchvision import datasets, transforms
import matplotlib.pyplot as plt

# %%
transform = transforms.Compose([transforms.ToTensor()])

# %%
dataset = datasets.MNIST('./MNIST_data/', download=True, train=False, transform=transform)
dataloader = torch.utils.data.DataLoader(dataset, batch_size=64, shuffle=False)

# %%
images, labels = next(iter(dataloader))

# %%
def imshow(img, label):
    plt.imshow(img.numpy().squeeze(), cmap='gray')
    plt.title(f"Label: {label}")

# %%
imshow(images[0], labels[0].item())
plt.show()

# %%
plt.figure(figsize=(10, 10))
for i in range(64):
    plt.subplot(8, 8, i + 1)
    imshow(images[i], labels[i].item())
    plt.axis('off')
plt.tight_layout()
plt.show()
